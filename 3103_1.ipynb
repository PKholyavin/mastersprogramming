# %% [markdown]
# Написать программу для игры в wordle. Программа сравнивает загаданное слово и слово, предложенное пользователем, и отмечает в гипотезе пользователя:
# а) буквы, стоящие на правильных местах
# б) буквы, присутствующие в загаданном слове, но стоящие на других местах
#
# Слова, которые можно загадывать, находятся в файле answerlist.txt. Слова, которые может предлагать пользователь, находятся в файле wordlist.txt

# %% [markdown]
# Загаданное слово / гипотеза пользователя / отметки букв
#
# флирт / филин / +??--
#
# стихи / филин / -?-?-
#
# абадб / агдад / +-??-
